# %% [markdown]
# # **Student Dropout Risk Prediction**

# %% [markdown]
# ## **Notebook 01 - Exploratory Data Analysis**

# %% [markdown]
# ###**Analyzing data**

# %%
#Understand dataset structure
import pandas as pd
df = pd.read_csv('../data/student.csv')
df.head()
# Out:
#   Marital status;Application mode;Application order;Course;"Daytime/evening attendance\t";Previous qualification;Previous qualification (grade);Nacionality;Mother's qualification;Father's qualification;Mother's occupation;Father's occupation;Admission grade;Displaced;Educational special needs;Debtor;Tuition fees up to date;Gender;Scholarship holder;Age at enrollment;International;Curricular units 1st sem (credited);Curricular units 1st sem (enrolled);Curricular units 1st sem (evaluations);Curricular units 1st sem (approved);Curricular units 1st sem (grade);Curricular units 1st sem (without evaluations);Curricular units 2nd sem (credited);Curricular units 2nd sem (enrolled);Curricular units 2nd sem (evaluations);Curricular units 2nd sem (approved);Curricular units 2nd sem (grade);Curricular units 2nd sem (without evaluations);Unemployment rate;Inflation rate;GDP;Target
# 0  1;17;5;171;1;1;122.0;1;19;12;5;9;127.3;1;0;0;1...
# 1  1;15;1;9254;1;1;160.0;1;1;3;3;3;142.5;1;0;0;0;...
# ...

# %%
import pandas as pd

df = pd.read_csv('../data/student.csv', sep=';')
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
df.shape
# Out:
# (4424, 37)

# %%
df.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance\t', 'Previous qualification',
#        'Previous qualification (grade)', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Admission grade',
#        'Displaced', 'Educational special needs', 'Debtor',
#        'Tuition fees up to date', 'Gender', 'Scholarship holder',
#        'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
# ...

# %%
df.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance\t  Previous qualification  \
# count                   4424.000000             4424.000000
# mean                       0.890823                4.577758
# std                        0.311897               10.216592
# min                        0.000000                1.000000
# ...

# %% [markdown]
# ###**checking empty cells**

# %%
df.isnull().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance\t                      0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### **Analyzing features**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.hist(df['Admission grade'], bins=20, edgecolor='black', color='skyblue')

plt.title('Distribution of Admission Grade')
plt.xlabel('Admission Grade')
plt.ylabel('Number of Students')

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df['Age at enrollment'],
         bins=15,
         edgecolor='black',
         color='lightgreen')

plt.title('Distribution of Age at Enrollment')
plt.xlabel('Age at Enrollment')
plt.ylabel('Number of Students')

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Curricular units 1st sem (grade)'],
         bins=20,
         edgecolor='black',
         color='orange')

plt.title('Distribution of Curricular Units 1st Semester Grade')
plt.xlabel('1st Semester Grade')
plt.ylabel('Number of Students')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Curricular units 2nd sem (grade)'],
         bins=20,
         edgecolor='black',
         color='purple')

plt.title('Distribution of Curricular Units 2nd Semester Grade')
plt.xlabel('2nd Semester Grade')
plt.ylabel('Number of Students')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(x='Target', data=df)

plt.title('Distribution of Student Status')
plt.xlabel('Target')
plt.ylabel('Count')

plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Gender', data=df)

plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')

plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Scholarship holder', data=df)

plt.title('Scholarship Holder Distribution')
plt.xlabel('Scholarship Holder')
plt.ylabel('Count')

plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Debtor', data=df)

plt.title('Debtor Distribution')
plt.xlabel('Debtor')
plt.ylabel('Count')

plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Tuition fees up to date', data=df)

plt.title('Tuition Fees Status')
plt.xlabel('Tuition Fees Up to Date')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# ### **Correlation**

# %%
import pandas as pd

numerical_cols = [
    'Admission grade',
    'Age at enrollment',
    'Previous qualification (grade)',
    'Curricular units 1st sem (approved)',
    'Curricular units 1st sem (grade)',
    'Curricular units 2nd sem (approved)',
    'Curricular units 2nd sem (grade)',
    'Unemployment rate',
    'Inflation rate',
    'GDP'
]

corr_matrix = df[numerical_cols].corr()

print(corr_matrix)
# Out:
#                                      Admission grade  Age at enrollment  \
# Admission grade                             1.000000          -0.029915
# Age at enrollment                          -0.029915           1.000000
# Previous qualification (grade)              0.580444          -0.111377
# Curricular units 1st sem (approved)         0.070892          -0.053405
# Curricular units 1st sem (grade)            0.073868          -0.156616
# Curricular units 2nd sem (approved)         0.076659          -0.112052
# Curricular units 2nd sem (grade)            0.074402          -0.173419
# Unemployment rate                           0.038756           0.025018
# Inflation rate                             -0.021624           0.025377
# GDP                                        -0.019519          -0.064678
#
#                                      Previous qualification (grade)  \
# Admission grade                                            0.580444
# ...

# %%
import seaborn as sns

numerical_cols = [
    'Admission grade',
    'Age at enrollment',
    'Previous qualification (grade)',
    'Curricular units 1st sem (approved)',
    'Curricular units 1st sem (grade)',
    'Curricular units 2nd sem (approved)',
    'Curricular units 2nd sem (grade)',
    'Unemployment rate',
    'Inflation rate',
    'GDP'
]

plt.figure(figsize=(10,8))

corr = df[numerical_cols].corr()

sns.heatmap(corr,
            annot=True,
            cmap='coolwarm',
            fmt='.2f')

plt.title('Correlation Heatmap')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['Target_encoded'] = le.fit_transform(df['Target'])

# %%
features = numerical_cols + ['Target_encoded']

corr_target = df[features].corr()

print(corr_target['Target_encoded'].sort_values(ascending=False))
# Out:
# Target_encoded                         1.000000
# Curricular units 2nd sem (approved)    0.624157
# Curricular units 2nd sem (grade)       0.566827
# Curricular units 1st sem (approved)    0.529123
# Curricular units 1st sem (grade)       0.485207
# Admission grade                        0.120889
# Previous qualification (grade)         0.103764
# GDP                                    0.044135
# Unemployment rate                      0.008627
# Inflation rate                        -0.026874
# Age at enrollment                     -0.243438
# Name: Target_encoded, dtype: float64

# %%
plt.figure(figsize=(6,8))

sns.heatmap(corr_target[['Target_encoded']],
            annot=True,
            cmap='coolwarm',
            fmt='.2f')

plt.title('Correlation with Target')
plt.show()

# %%
df.to_csv("../data/cleaned_student.csv", sep=";", index=False)
